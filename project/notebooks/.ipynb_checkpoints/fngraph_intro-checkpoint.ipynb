# %% [markdown]
# # Top 5 Reasons **Fn-Graph** is **F'n Great**
# - Simplify your workflow.
# - Improve your code understandability
# - It's lightweight framework
# - Every step is cached great for quick exploration
# - Interactive Explorer
#
# <br><br><br><br>
#
# ## #5 Simplify your workflow.
#
# ### 5A. Plan Features
# <img src="attachment:e92cdc89-fc18-46f3-88d1-3564e360b1ee.png" alt="Drawing" style="width: 300px;"/>
#
# ### 5B. Visualize your workflow
# <img src="attachment:506e74cc-a1ad-4c54-9780-622fc90cfe6c.png" alt="Drawing" style="width: 300px;"/>
#
# <br><br><br><br>
#
# ## #4 Improve your code understandability
#
# ### 4A. Modularize your work!
# <img src="attachment:eec7fbc5-949f-4d6b-8785-0575e8d90e9c.png" alt="Drawing" style="width: 500px;"/>
#
# ### 4A. Debug easier as a result.
# <img src="attachment:8f6e574b-931e-40b0-9a83-179ee15041b0.png" alt="Drawing" style="width: 600px;"/>
#
# <br><br><br><br>
#
# ## #3 FN_Graph is light weight:
# <img src="attachment:63503c29-6131-4310-ab46-39659818f4f6.png" alt="Drawing" style="width: 500px;"/>
#
# <br><br><br><br>
#
# ## #2 Inspect every single step through cached results
# <img src="attachment:747b4416-adbf-426b-b817-e504bbbeb41b.png" alt="Drawing" style="width: 900px;"/>
#
# <br><br><br><br>
#
# ## #1 Interactive Explorer. Feels like using Alteryx.
# <img src="attachment:22d2a781-41e6-4818-9302-0564cecb351c.png" alt="Drawing" style="width: 900px;"/>
